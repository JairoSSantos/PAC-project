# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from skimage import color, util, transform as trans, filters, feature
import os
from scipy import ndimage, signal
from sklearn import cluster
from sklearn.neighbors import KernelDensity

# %%
images_path = os.path.join('dataset', 'images')

def get(filename):
    return np.array(Image.open(os.path.join(images_path, filename)))

def by_id(i):
    return get(f'{i}.jpg')

def random_images(k=1):
    return tuple(map(get, np.random.choice(os.listdir(images_path), k)))

def hsv_gray(image):
    return color.rgb2gray(color.rgb2hsv(image))

def levels(image, f=np.nansum):
    return f(image, axis=0), f(image, axis=1)

def freqs(image):
    w, h = image.shape
    freq_x = np.fft.fftfreq(w, 1)
    freq_y = np.fft.fftfreq(h, 1)
    fft_x = np.abs(np.fft.fft(np.nansum(image, axis=1)))
    fft_y = np.abs(np.fft.fft(np.nansum(image, axis=0)))
    vals_x, vals_y = freq_x[fft_x == np.sort(fft_x)[-2]], freq_y[fft_y == np.sort(fft_y)[-2]]
    return np.abs(vals_x[0]), np.abs(vals_y[0])

def fft2d(image):
    return np.fft.fftshift(np.fft.fft2(np.fft.ifftshift(image)))

def ifft2d(image):
    return np.fft.fftshift(np.fft.ifft2(np.fft.ifftshift(image)))

def peaks_filter(x:np.array, y:np.array, peaks:np.array, k:int=1):
    ypeaks = y[peaks]
    max_peak = peaks[ypeaks == ypeaks.max()]
    for _ in range(k-1):
        max_peak = peaks[ypeaks == ypeaks[np.isin(ypeaks, y[x < x[max_peak][0]])].max()]
    return max_peak

def pixel_scale(image:np.array):
    fft = np.abs(fft2d(image))
    xfreqs = np.fft.ifftshift(np.fft.fftfreq(fft.shape[0], 1))
    yfreqs = np.fft.ifftshift(np.fft.fftfreq(fft.shape[1], 1))
    
    ymean = np.mean(fft, axis=1)
    xmean = np.mean(fft, axis=0)
    
    (ypeaks, _), (xpeaks, _) = signal.find_peaks(ymean), signal.find_peaks(xmean)
    Py = peaks_filter(yfreqs, ymean, ypeaks, 2)
    Px = peaks_filter(xfreqs, xmean, xpeaks, 2)
    
    return np.abs(xfreqs[Px][0]), np.abs(xfreqs[Py][0])

# %%
image = random_images()[0]
img = util.invert(color.rgb2gray(image))
plt.imshow(img, cmap='gray')

# %%
graph_area = np.ones(img.shape)
graph_area[img.shape[0]//5:-img.shape[0]//5, img.shape[1]//5:-img.shape[1]//5] = np.nan
fimg = img.copy()*graph_area #filters.gaussian(filters.sobel(img), 2) #filters.gaussian(feature.canny(img), 2)
plt.plot(fimg, 'b-', alpha=0.01)
plt.plot(np.nanmean(fimg, axis=0), 'r-')
plt.plot(np.nanstd(fimg, axis=0), 'g-')
plt.show()

# %%
fft = np.abs(fft2d(img))
xfreqs = np.fft.ifftshift(np.fft.fftfreq(fft.shape[0], 1))
yfreqs = np.fft.ifftshift(np.fft.fftfreq(fft.shape[1], 1))
plt.imshow(fft[(xfreqs != 0) &  (yfreqs != 0)])

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 2))
ymean = np.mean(fft, axis=1)
xmean = np.mean(fft, axis=0)
ystd = np.std(fft, axis=1)
xstd = np.std(fft, axis=0)
axs[0].plot(yfreqs, ymean)
axs[1].plot(xfreqs, xmean)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 2))
(ypeaks, _), (xpeaks, _) = signal.find_peaks(ymean), signal.find_peaks(xmean)
Py = peaks_filter(yfreqs, ymean, ypeaks, 2)
Px = peaks_filter(xfreqs, xmean, xpeaks, 2)

print(
    yfreqs[peaks_filter(yfreqs, ystd, signal.find_peaks(ystd)[0], 2)],
    xfreqs[peaks_filter(xfreqs, xstd, signal.find_peaks(xstd)[0], 2)]
)

axs[0].plot(yfreqs, ymean)
axs[0].plot(yfreqs[ypeaks], ymean[ypeaks], '+')
axs[0].plot(yfreqs[Py], ymean[Py], 'o')
axs[1].plot(xfreqs, xmean)
axs[1].plot(xfreqs[xpeaks], xmean[xpeaks], '+')
axs[1].plot(xfreqs[Px], xmean[Px], 'o')
# Out:
# [-0.0625] [-0.0625]

# %%
xfreqs[Px][0], yfreqs[Py][0]
# Out:
# (-0.0625, -0.0625)

# %%
def pixel_scale_1d(sig1d:np.array):
    fft = np.abs(np.fft.fftshift(np.fft.fft(np.fft.ifftshift(sig1d))))
    freqs = np.fft.ifftshift(np.fft.fftfreq(len(fft), 1))
    
    peaks, _ = signal.find_peaks(fft)
    P = peaks_filter(freqs, fft, peaks, 2)
    
    return np.abs(freqs[P][0])

# %%
FX = np.apply_along_axis(pixel_scale_1d, axis=0, arr=img)
FY = np.apply_along_axis(pixel_scale_1d, axis=1, arr=img)
pixel_scale(img)
# Out:
# (0.0703125, 0.0703125)

# %%
FX.mean(), FX.std(), np.median(FX),
# Out:
# (0.06396484375, 0.02348830756016737, 0.0703125)

# %%
FY.mean(), FY.std(), np.median(FY)
# Out:
# (0.0621795654296875, 0.020134242476267418, 0.0703125)
