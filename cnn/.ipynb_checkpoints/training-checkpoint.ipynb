# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os

# %% [markdown]
# # Importando os dados

# %%
INFO_PATH = os.path.join('dataset', 'dataset.csv')
IMAGES_PATH = os.path.join('dataset', 'images')

# %%
ds = pd.read_csv(INFO_PATH)
ds
# Out:
#     filename     area
# 0      0.jpg  100.473
# 1      1.jpg  127.880
# 2      2.jpg  161.820
# 3      3.jpg  190.003
# 4      4.jpg   22.713
# ..       ...      ...
# 350  350.jpg   98.599
# 351  351.jpg   98.599
# 352  352.jpg   98.599
# 353  353.jpg   98.599
# 354  354.jpg   98.599
#
# [355 rows x 2 columns]

# %%
images = np.array([np.asarray(keras.utils.load_img(os.path.join(IMAGES_PATH, filename), color_mode='grayscale'))
               for filename in ds.filename])

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 8))

for ax, (_, area, im) in zip(axs.flat, ds.sample(len(axs.flat)).values):
    ax.imshow(im, cmap='gray')
    ax.set_title(area)
    
plt.show()

# %% [markdown]
# # Treinamento

# %%
model = keras.Sequential((
    keras.layers.Rescaling(1/255, input_shape=(256, 256, 1)),
    keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
    keras.layers.MaxPooling2D(),
    keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
    keras.layers.MaxPooling2D(),
    keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
    keras.layers.MaxPooling2D(),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(1, activation='linear')
))
model.compile(optimizer='adam', loss='mean_absolute_percentage_error')

# %%
history = model.fit(images, ds.area, batch_size=40, validation_split=0.3, epochs=30)
# Out:
# Epoch 1/30
# 7/7 [==============================] - 121s 17s/step - loss: 4.6721 - val_loss: 12.4656
# Epoch 2/30
# 7/7 [==============================] - 83s 11s/step - loss: 3.6509 - val_loss: 14.3392
# Epoch 3/30
# 7/7 [==============================] - 74s 11s/step - loss: 4.7547 - val_loss: 12.7995
# Epoch 4/30
# 7/7 [==============================] - 80s 12s/step - loss: 4.1954 - val_loss: 14.1740
# Epoch 5/30
# 5/7 [====================>.........] - ETA: 25s - loss: 4.5389
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 history = model.fit(images, ds.area, batch_size=40, validation_split=0.3, epochs=30)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ...

# %%
loss = history.history['loss']
plt.plot(range(len(loss)), loss)
plt.plot(range(len(loss)), history.history['val_loss'])
plt.show()
