# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Github/PAC/cnn
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Github/PAC/cnn

# %%
import data
import aimodel
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from skimage.color import label2rgb

# %%
img, lbl = data.get_random(seed=4)
height, width = lbl.shape
img = tf.convert_to_tensor(img[np.newaxis, :, :, np.newaxis])
lbl = tf.convert_to_tensor(lbl[np.newaxis, :, :, np.newaxis].astype(float))
assert img.shape == lbl.shape == (1, height, width, 1)

# %%
edge = tf.reduce_any(tf.image.sobel_edges(lbl) != 0, axis=-1)[0, :, :, 0]
assert edge.shape == (height, width)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 3))
ax1.imshow(label2rgb(lbl[0, :, :, 0].numpy(), img[0, :, :, 0].numpy(), bg_label=0)); ax1.axis('off')
ax2.imshow(edge); ax2.axis('off')

fig.tight_layout()
plt.show()

# %%
X, Y = tf.meshgrid(tf.range(width, dtype=float), tf.range(height, dtype=float))
Ex = X[edge][tf.newaxis, tf.newaxis, :] # Ex.shape = [1, 1, edge_pixels]
Ey = Y[edge][tf.newaxis, tf.newaxis, :] # Ey.shape = [1, 1, edge_pixels]
R = tf.sqrt((Ex - X[:, :, tf.newaxis])**2 + (Ey - Y[:, :, tf.newaxis])**2)
assert R.shape == (height, width, Ex.shape[-1])
Ex.shape, Ey.shape, R.shape
# Out:
# (TensorShape([1, 1, 1117]),
#  TensorShape([1, 1, 1117]),
#  TensorShape([256, 256, 1117]))

# %%
W = 1 + norm(tf.sqrt(tf.reduce_min(tf.where(lbl == 0, R, 0), axis=-1)))[0]

fig = plt.figure(figsize=(6, 3))
ax1 = fig.add_subplot(121); ax1.axis('off')
ax2 = fig.add_subplot(122, projection='3d'); ax2.axis('off')

ax1.imshow(W, cmap='magma')
ax2.plot_surface(X, Y, W, cmap='magma')

fig.tight_layout()
plt.show()

# %%
# %%time
N = 8
imgs, lbls = data.get_random(N, seed=123, as_tensor=True)
Ws = data.get_weights(lbls)
Ws.shape
# Out:
# CPU times: total: 1min 53s
# Wall time: 1min 17s
# TensorShape([8, 256, 256, 1])

# %%
fig = plt.figure(figsize=(2*N, 6))

for i in range(N):
    ax1 = fig.add_subplot(3, N, i + 1); ax1.axis('off')
    ax2 = fig.add_subplot(3, N, i + N + 1); ax2.axis('off')
    ax3 = fig.add_subplot(3, N, i + 2*N + 1, projection='3d'); ax3.axis('off')

    lbl = tf.squeeze(lbls[i%N])
    w = tf.squeeze(Ws[i%N])
    ax1.imshow(lbl, cmap='gray')
    ax2.imshow(w, cmap='magma')
    ax3.plot_surface(*np.meshgrid(np.arange(lbls.shape[2]), np.arange(lbls.shape[1])), w, cmap='magma')

fig.tight_layout()
plt.show()

# %%
(x_train, y_train), (x_test, y_test) = data.load_dataset(as_tensor=True, augmentation=False)

# %%
Y_train = tf.stack((get_weight(tf.convert_to_tensor(y_train.astype(float)))[:, :, :, tf.newaxis], y_train), axis=1)
Y_test = tf.stack((get_weight(tf.convert_to_tensor(y_test.astype(float)))[:, :, :, tf.newaxis], y_test), axis=1)
Y_train.shape, Y_test.shape
# Out:
# (TensorShape([47, 2, 256, 256, 1]), TensorShape([16, 2, 256, 256, 1]))

# %%
class Loss (tf.keras.losses.Loss):
    def __init__(self):
        super().__init__()
    
    def call(self, y_true, y_pred):
        w = y_true[:, 0, :, :, :]
        lbl = y_true[:, 1, :, :, :]
        N = tf.multiply(*tf.cast(y_pred.shape, float)[1:-1])/tf.reduce_sum(y_pred, axis=(1, 2, 3))
        return tf.reduce_mean(w[:, :, :, 0]*tf.keras.metrics.binary_crossentropy(lbl, y_pred), axis=(1, 2))*N

# %%
unet = aimodel.build_unet((256, 256, 1), (16, 32, 64))
unet.compile(optimizer=tf.keras.optimizers.Adam(), loss=Loss())

# %%
tf.config.run_functions_eagerly(True)
history = unet.fit(x_train, Y_train, epochs=150, batch_size=len(x_train)//6, validation_data=(x_test, Y_test))
# Out:
# Epoch 1/150
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/structured_function.py:264: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 7/7 [==============================] - 33s 5s/step - loss: 1.8976 - val_loss: 1.9939
# Epoch 2/150
# 7/7 [==============================] - 25s 4s/step - loss: 1.3719 - val_loss: 1.9799
# Epoch 3/150
# 7/7 [==============================] - 25s 4s/step - loss: 1.0760 - val_loss: 2.0574
# Epoch 4/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.9256 - val_loss: 2.5589
# Epoch 5/150
# 7/7 [==============================] - 27s 4s/step - loss: 0.8307 - val_loss: 3.4297
# Epoch 6/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.7711 - val_loss: 4.1132
# Epoch 7/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.7143 - val_loss: 4.6641
# Epoch 8/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.6742 - val_loss: 5.7943
# Epoch 9/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.6278 - val_loss: 5.6752
# Epoch 10/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.5949 - val_loss: 6.3688
# Epoch 11/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.5531 - val_loss: 6.3402
# Epoch 12/150
# 7/7 [==============================] - 28s 4s/step - loss: 0.5155 - val_loss: 6.3414
# Epoch 13/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.4814 - val_loss: 6.5655
# Epoch 14/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.4477 - val_loss: 6.7774
# Epoch 15/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.4201 - val_loss: 6.7100
# Epoch 16/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.3941 - val_loss: 6.0045
# Epoch 17/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.3714 - val_loss: 7.5146
# Epoch 18/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.3543 - val_loss: 6.4950
# Epoch 19/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.3478 - val_loss: 6.5367
# Epoch 20/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.3143 - val_loss: 6.8315
# Epoch 21/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.3004 - val_loss: 6.9881
# Epoch 22/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.2733 - val_loss: 6.3181
# Epoch 23/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.2515 - val_loss: 7.2631
# Epoch 24/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.2384 - val_loss: 6.0922
# Epoch 25/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.2332 - val_loss: 6.8950
# Epoch 26/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.2261 - val_loss: 8.1546
# Epoch 27/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.2149 - val_loss: 6.7979
# Epoch 28/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1995 - val_loss: 7.7543
# Epoch 29/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1837 - val_loss: 7.4935
# Epoch 30/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1706 - val_loss: 6.9126
# Epoch 31/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1656 - val_loss: 6.4972
# Epoch 32/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1730 - val_loss: 6.3062
# Epoch 33/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1577 - val_loss: 6.7141
# Epoch 34/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1458 - val_loss: 5.9737
# Epoch 35/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1392 - val_loss: 7.4596
# Epoch 36/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1373 - val_loss: 6.0399
# Epoch 37/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1311 - val_loss: 6.9737
# Epoch 38/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1252 - val_loss: 5.7447
# Epoch 39/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1264 - val_loss: 6.3904
# Epoch 40/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1262 - val_loss: 5.6482
# Epoch 41/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1157 - val_loss: 6.0345
# Epoch 42/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1071 - val_loss: 5.7544
# Epoch 43/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1042 - val_loss: 4.8864
# Epoch 44/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1035 - val_loss: 5.3981
# Epoch 45/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0993 - val_loss: 5.4236
# Epoch 46/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0950 - val_loss: 4.1282
# Epoch 47/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0953 - val_loss: 5.2889
# Epoch 48/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0969 - val_loss: 4.1269
# Epoch 49/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0859 - val_loss: 4.9388
# Epoch 50/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0873 - val_loss: 3.7138
# Epoch 51/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0796 - val_loss: 4.6184
# Epoch 52/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0772 - val_loss: 3.9083
# Epoch 53/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0792 - val_loss: 4.6323
# Epoch 54/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0744 - val_loss: 3.9593
# Epoch 55/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0727 - val_loss: 3.3939
# Epoch 56/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0662 - val_loss: 3.4202
# Epoch 57/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0668 - val_loss: 2.6653
# Epoch 58/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0643 - val_loss: 2.7541
# Epoch 59/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0687 - val_loss: 2.4320
# Epoch 60/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0641 - val_loss: 3.1708
# Epoch 61/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0647 - val_loss: 2.4785
# Epoch 62/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0659 - val_loss: 3.1307
# Epoch 63/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0671 - val_loss: 2.2649
# Epoch 64/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0704 - val_loss: 2.1682
# Epoch 65/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0610 - val_loss: 2.0115
# Epoch 66/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0547 - val_loss: 1.9019
# Epoch 67/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0573 - val_loss: 2.0273
# Epoch 68/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0504 - val_loss: 2.4026
# Epoch 69/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0505 - val_loss: 1.8085
# Epoch 70/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0495 - val_loss: 1.6611
# Epoch 71/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0472 - val_loss: 1.6926
# Epoch 72/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0446 - val_loss: 1.8094
# Epoch 73/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0433 - val_loss: 1.2345
# Epoch 74/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0514 - val_loss: 1.4023
# Epoch 75/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0430 - val_loss: 1.1732
# Epoch 76/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0410 - val_loss: 1.2413
# Epoch 77/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0442 - val_loss: 1.2668
# Epoch 78/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0395 - val_loss: 1.2054
# Epoch 79/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0403 - val_loss: 0.9066
# Epoch 80/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0421 - val_loss: 0.9365
# Epoch 81/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0410 - val_loss: 0.9671
# Epoch 82/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0400 - val_loss: 1.0192
# Epoch 83/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0388 - val_loss: 0.9658
# Epoch 84/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0423 - val_loss: 0.9627
# Epoch 85/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0409 - val_loss: 1.1084
# Epoch 86/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0446 - val_loss: 0.6243
# Epoch 87/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0439 - val_loss: 0.4187
# Epoch 88/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0458 - val_loss: 0.2951
# Epoch 89/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0426 - val_loss: 0.5085
# Epoch 90/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0384 - val_loss: 0.4510
# Epoch 91/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0416 - val_loss: 0.4700
# Epoch 92/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0450 - val_loss: 0.3251
# Epoch 93/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0386 - val_loss: 0.3600
# Epoch 94/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0390 - val_loss: 0.7544
# Epoch 95/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0409 - val_loss: 0.4922
# Epoch 96/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0380 - val_loss: 0.4863
# Epoch 97/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0371 - val_loss: 0.7434
# Epoch 98/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0399 - val_loss: 0.5198
# Epoch 99/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0323 - val_loss: 0.4345
# Epoch 100/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0297 - val_loss: 0.6228
# Epoch 101/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0291 - val_loss: 0.4524
# Epoch 102/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0300 - val_loss: 0.4577
# Epoch 103/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0281 - val_loss: 0.5717
# Epoch 104/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0265 - val_loss: 0.5038
# Epoch 105/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0260 - val_loss: 0.4138
# Epoch 106/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0271 - val_loss: 0.5026
# Epoch 107/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0240 - val_loss: 0.4519
# Epoch 108/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0257 - val_loss: 0.3601
# Epoch 109/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0263 - val_loss: 0.5365
# Epoch 110/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0285 - val_loss: 0.6206
# Epoch 111/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0264 - val_loss: 0.3777
# Epoch 112/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0270 - val_loss: 0.3395
# Epoch 113/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0250 - val_loss: 0.4389
# Epoch 114/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0242 - val_loss: 0.4254
# Epoch 115/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0254 - val_loss: 0.3715
# Epoch 116/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0271 - val_loss: 0.5535
# Epoch 117/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0258 - val_loss: 0.4760
# Epoch 118/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0246 - val_loss: 0.3216
# Epoch 119/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0243 - val_loss: 0.3678
# Epoch 120/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0247 - val_loss: 0.4436
# Epoch 121/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0209 - val_loss: 0.3661
# Epoch 122/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0205 - val_loss: 0.3669
# Epoch 123/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0207 - val_loss: 0.4026
# Epoch 124/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0212 - val_loss: 0.3230
# Epoch 125/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0199 - val_loss: 0.3463
# Epoch 126/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0208 - val_loss: 0.3265
# Epoch 127/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0213 - val_loss: 0.4810
# Epoch 128/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0239 - val_loss: 0.3708
# Epoch 129/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0245 - val_loss: 0.4123
# Epoch 130/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0213 - val_loss: 0.8132
# Epoch 131/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0206 - val_loss: 0.5389
# Epoch 132/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0243 - val_loss: 0.4970
# Epoch 133/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0204 - val_loss: 0.4808
# Epoch 134/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0214 - val_loss: 0.5001
# Epoch 135/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0194 - val_loss: 0.4130
# Epoch 136/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0206 - val_loss: 0.3768
# Epoch 137/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0243 - val_loss: 0.3651
# Epoch 138/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0251 - val_loss: 0.8857
# Epoch 139/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0227 - val_loss: 0.4886
# Epoch 140/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0223 - val_loss: 0.3750
# Epoch 141/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0220 - val_loss: 0.3571
# Epoch 142/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0215 - val_loss: 0.5120
# Epoch 143/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0206 - val_loss: 0.7135
# Epoch 144/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0183 - val_loss: 0.3804
# Epoch 145/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0190 - val_loss: 0.4808
# Epoch 146/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0157 - val_loss: 0.5128
# Epoch 147/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0162 - val_loss: 0.5569
# Epoch 148/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0160 - val_loss: 0.5296
# Epoch 149/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0147 - val_loss: 0.4923
# Epoch 150/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0144 - val_loss: 0.6482

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.semilogy()
# Out:
# []

# %%
class Loss2 (tf.keras.losses.Loss):
    def __init__(self):
        super().__init__()
    
    def call(self, y_true, y_pred):
        w = y_true[:, 0, :, :, :]
        lbl = y_true[:, 1, :, :, :]
        Ap_true = tf.reduce_sum(lbl, axis=(1, 2, 3))
        Ap_pred = tf.reduce_sum(y_pred, axis=(1, 2, 3))
        N = tf.multiply(*tf.cast(y_pred.shape, float)[1:-1])/Ap_pred
        WB = tf.reduce_mean(w[:, :, :, 0]*tf.keras.losses.binary_crossentropy(lbl, y_pred), axis=(1, 2))*N
        MP = tf.losses.MAPE(Ap_true, Ap_pred)*1e-2
        return WB + MP

# %%
unet = aimodel.build_unet((256, 256, 1), (16, 32, 64))
unet.compile(optimizer=tf.keras.optimizers.Adam(), loss=Loss2())

# %%
tf.config.run_functions_eagerly(True)
history = unet.fit(x_train, Y_train, epochs=150, batch_size=len(x_train)//6, validation_data=(x_test, Y_test))
# Out:
# Epoch 1/150
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/structured_function.py:264: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 7/7 [==============================] - 30s 4s/step - loss: 3.4305 - val_loss: 3.7027
# Epoch 2/150
# 7/7 [==============================] - 29s 4s/step - loss: 2.8076 - val_loss: 3.8403
# Epoch 3/150
# 7/7 [==============================] - 29s 4s/step - loss: 2.3288 - val_loss: 4.5384
# Epoch 4/150
# 7/7 [==============================] - 29s 4s/step - loss: 2.0882 - val_loss: 5.8299
# Epoch 5/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.8757 - val_loss: 7.5298
# Epoch 6/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.7567 - val_loss: 9.1441
# Epoch 7/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.6598 - val_loss: 10.0271
# Epoch 8/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.5440 - val_loss: 9.5890
# Epoch 9/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.4827 - val_loss: 10.0762
# Epoch 10/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.3947 - val_loss: 10.9135
# Epoch 11/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.3161 - val_loss: 10.4696
# Epoch 12/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.2498 - val_loss: 11.1900
# Epoch 13/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.1695 - val_loss: 11.3869
# Epoch 14/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.1170 - val_loss: 10.8592
# Epoch 15/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.0462 - val_loss: 12.5135
# Epoch 16/150
# 7/7 [==============================] - 29s 4s/step - loss: 1.0142 - val_loss: 11.5132
# Epoch 17/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.9398 - val_loss: 11.5100
# Epoch 18/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.8934 - val_loss: 11.7999
# Epoch 19/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.8444 - val_loss: 11.8582
# Epoch 20/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.8011 - val_loss: 11.3775
# Epoch 21/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.7681 - val_loss: 11.6106
# Epoch 22/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.7154 - val_loss: 11.0825
# Epoch 23/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.6773 - val_loss: 11.4877
# Epoch 24/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.6379 - val_loss: 10.9934
# Epoch 25/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.6173 - val_loss: 10.6830
# Epoch 26/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.5994 - val_loss: 10.7999
# Epoch 27/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.5503 - val_loss: 10.6279
# Epoch 28/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.5332 - val_loss: 10.2892
# Epoch 29/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.5174 - val_loss: 10.3823
# Epoch 30/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.4786 - val_loss: 10.1623
# Epoch 31/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.5029 - val_loss: 13.1659
# Epoch 32/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.4778 - val_loss: 11.4238
# Epoch 33/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.4316 - val_loss: 10.5806
# Epoch 34/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.4206 - val_loss: 10.6139
# Epoch 35/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.4159 - val_loss: 9.8932
# Epoch 36/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.3901 - val_loss: 10.2385
# Epoch 37/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.3541 - val_loss: 9.6681
# Epoch 38/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.3418 - val_loss: 9.5135
# Epoch 39/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.3689 - val_loss: 9.9326
# Epoch 40/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.3567 - val_loss: 11.0162
# Epoch 41/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.3251 - val_loss: 10.3485
# Epoch 42/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.2975 - val_loss: 10.2509
# Epoch 43/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.3029 - val_loss: 9.0385
# Epoch 44/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.2809 - val_loss: 8.3700
# Epoch 45/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.2528 - val_loss: 8.6405
# Epoch 46/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.2430 - val_loss: 7.9440
# Epoch 47/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.2332 - val_loss: 7.7185
# Epoch 48/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.2465 - val_loss: 7.0123
# Epoch 49/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.2203 - val_loss: 8.3534
# Epoch 50/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.2209 - val_loss: 7.2586
# Epoch 51/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.2099 - val_loss: 8.1955
# Epoch 52/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.2063 - val_loss: 6.9411
# Epoch 53/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1993 - val_loss: 7.2106
# Epoch 54/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1963 - val_loss: 6.0464
# Epoch 55/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1898 - val_loss: 6.4974
# Epoch 56/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1929 - val_loss: 5.9451
# Epoch 57/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1938 - val_loss: 5.4427
# Epoch 58/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1649 - val_loss: 4.6109
# Epoch 59/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.1783 - val_loss: 5.3469
# Epoch 60/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.1683 - val_loss: 4.6992
# Epoch 61/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1576 - val_loss: 4.5986
# Epoch 62/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1583 - val_loss: 3.0614
# Epoch 63/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1793 - val_loss: 5.7617
# Epoch 64/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1632 - val_loss: 4.3661
# Epoch 65/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1545 - val_loss: 5.2474
# Epoch 66/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1637 - val_loss: 2.9804
# Epoch 67/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1564 - val_loss: 3.5466
# Epoch 68/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1414 - val_loss: 3.3236
# Epoch 69/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1396 - val_loss: 3.8884
# Epoch 70/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.1249 - val_loss: 3.4641
# Epoch 71/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1353 - val_loss: 2.6330
# Epoch 72/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1391 - val_loss: 1.9134
# Epoch 73/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1210 - val_loss: 1.6505
# Epoch 74/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.1197 - val_loss: 1.4897
# Epoch 75/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1145 - val_loss: 1.5285
# Epoch 76/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1102 - val_loss: 1.3592
# Epoch 77/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.1050 - val_loss: 1.4073
# Epoch 78/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.1232 - val_loss: 1.1761
# Epoch 79/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1113 - val_loss: 1.8666
# Epoch 80/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1163 - val_loss: 1.3384
# Epoch 81/150
# 7/7 [==============================] - 36s 5s/step - loss: 0.1109 - val_loss: 1.2836
# Epoch 82/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.1100 - val_loss: 2.6306
# Epoch 83/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.1204 - val_loss: 1.8577
# Epoch 84/150
# 7/7 [==============================] - 32s 5s/step - loss: 0.1047 - val_loss: 1.7388
# Epoch 85/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.1053 - val_loss: 0.9567
# Epoch 86/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0943 - val_loss: 0.9811
# Epoch 87/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0927 - val_loss: 0.7027
# Epoch 88/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0850 - val_loss: 0.7036
# Epoch 89/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0850 - val_loss: 0.7415
# Epoch 90/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0953 - val_loss: 0.9319
# Epoch 91/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0894 - val_loss: 0.7370
# Epoch 92/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0917 - val_loss: 1.1470
# Epoch 93/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0816 - val_loss: 0.9714
# Epoch 94/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0860 - val_loss: 1.0293
# Epoch 95/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0862 - val_loss: 0.7030
# Epoch 96/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0769 - val_loss: 1.3099
# Epoch 97/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0855 - val_loss: 0.6003
# Epoch 98/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0766 - val_loss: 0.7944
# Epoch 99/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0873 - val_loss: 1.0716
# Epoch 100/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0779 - val_loss: 0.8143
# Epoch 101/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0802 - val_loss: 0.4611
# Epoch 102/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0737 - val_loss: 0.4169
# Epoch 103/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0671 - val_loss: 0.4523
# Epoch 104/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0715 - val_loss: 0.3835
# Epoch 105/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0694 - val_loss: 0.7005
# Epoch 106/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0682 - val_loss: 0.5363
# Epoch 107/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0620 - val_loss: 0.6816
# Epoch 108/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0645 - val_loss: 0.5224
# Epoch 109/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0645 - val_loss: 0.7187
# Epoch 110/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0675 - val_loss: 0.5295
# Epoch 111/150
# 7/7 [==============================] - 32s 5s/step - loss: 0.0663 - val_loss: 0.8232
# Epoch 112/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0706 - val_loss: 0.6297
# Epoch 113/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0584 - val_loss: 0.8586
# Epoch 114/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0613 - val_loss: 0.5316
# Epoch 115/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0610 - val_loss: 0.7187
# Epoch 116/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0605 - val_loss: 0.5692
# Epoch 117/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0565 - val_loss: 0.5738
# Epoch 118/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0603 - val_loss: 0.5239
# Epoch 119/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0571 - val_loss: 0.5367
# Epoch 120/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0551 - val_loss: 0.5194
# Epoch 121/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0575 - val_loss: 0.6534
# Epoch 122/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0574 - val_loss: 0.8655
# Epoch 123/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0583 - val_loss: 0.9094
# Epoch 124/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0526 - val_loss: 0.7245
# Epoch 125/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0527 - val_loss: 0.4782
# Epoch 126/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0496 - val_loss: 0.5573
# Epoch 127/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0529 - val_loss: 0.6139
# Epoch 128/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0557 - val_loss: 0.4837
# Epoch 129/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0600 - val_loss: 0.4988
# Epoch 130/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0513 - val_loss: 0.5163
# Epoch 131/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0522 - val_loss: 0.5233
# Epoch 132/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0510 - val_loss: 0.4282
# Epoch 133/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0524 - val_loss: 0.7059
# Epoch 134/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0466 - val_loss: 0.8522
# Epoch 135/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0442 - val_loss: 0.5525
# Epoch 136/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0436 - val_loss: 0.4666
# Epoch 137/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0434 - val_loss: 0.6790
# Epoch 138/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0441 - val_loss: 0.5419
# Epoch 139/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0475 - val_loss: 0.6768
# Epoch 140/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0398 - val_loss: 0.7878
# Epoch 141/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0409 - val_loss: 0.6143
# Epoch 142/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0397 - val_loss: 0.7564
# Epoch 143/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0414 - val_loss: 0.6537
# Epoch 144/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0379 - val_loss: 0.5391
# Epoch 145/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0471 - val_loss: 0.5032
# Epoch 146/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0390 - val_loss: 0.4865
# Epoch 147/150
# 7/7 [==============================] - 29s 4s/step - loss: 0.0386 - val_loss: 0.5420
# Epoch 148/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0406 - val_loss: 0.7684
# Epoch 149/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0373 - val_loss: 0.7508
# Epoch 150/150
# 7/7 [==============================] - 30s 4s/step - loss: 0.0353 - val_loss: 0.6372

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.semilogy()
# Out:
# []
