# %%
from model import *
from data import *
import matplotlib.pyplot as plt
import time
from os import listdir

# %%
outs = {
    'predict':[],
    'estimated_error':[],
    'exe_time':[]
}
model = FourierGabor(nclusters=3, nbins=50, opening=10, dilation=5)
total = len(DS)
for i, filename in enumerate(DS.filename):
    tic = time.process_time()
    area, error = model.predict(get(filename), True)
    outs['exe_time'].append(time.process_time() - tic)
    outs['predict'].append(area)
    outs['estimated_error'].append(error)
    pi = int(np.mean(outs['exe_time']))
    et = int((total-i)*pi)
    print(f'{filename}\t{i+1}/{total}\t{(i/total*100):.2f}%\tPI:{pi}s\tET:{et//60}:{et%60}', end='\r')
# Out:
# 354.jpg	355/355	99.72%	PI:4s	ET:0:422

# %%
dss = pd.concat([DS, pd.DataFrame(outs)], axis=1).sort_values('area', ignore_index=True)
dss['error'] = dss.area - dss.predict
dss['error_rel'] = np.abs(dss.error)/dss.area*100

# %%
plt.plot(dss.area, '.', label='Valor real')
plt.plot(dss.predict, '+', c='tab:red', label='Valor encontrado', lw=0.7)
plt.ylabel(r'Área ($mm^2$)')
plt.xlabel('Amostra')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
plt.plot(dss.area, dss.predict, 'o', alpha=0.5)
ax.set_aspect('equal', 'box')
plt.xlim(0, 210)
plt.ylim(0, 210)
plt.xlabel(r'Área Real ($mm^2$)')
plt.ylabel(r'Área Encontrada ($mm^2$)')
plt.plot(np.arange(0, 210), 'k--', label=r'$y=x$')
plt.legend()
plt.show()

# %%
dss.error_rel.describe()
# Out:
# count    355.000000
# mean       4.629711
# std        5.892771
# min        0.121499
# 25%        1.896272
# 50%        3.266587
# 75%        7.025987
# max       96.587042
# Name: error_rel, dtype: float64

# %%
plt.plot(dss.estimated_error, dss.error_rel, 'o', alpha=0.1)

# %%
dss[dss.error_rel > 50]
# Out:
#     filename    area     predict  estimated_error  exe_time      error  \
# 184  324.jpg  85.547  168.174316        34.106842  3.796875 -82.627316
#
#      error_rel
# 184  96.587042

# %%
dss.exe_time.describe()
# Out:
# count    355.000000
# mean       4.270951
# std        2.471319
# min        1.281250
# 25%        3.351562
# 50%        3.921875
# 75%        4.945312
# max       17.468750
# Name: exe_time, dtype: float64

# %%
dss.to_csv('dss_predict.csv', index=False)

# %%
img, fname = next(random_images(names=True))
img = rgb2gray(img)
img = rotate(img, find_slope(img), mode='reflect')
plt.imshow(img, cmap='gray')

# %%
pixel_scale_edge(img)
# Out:
# (0.0625, 0.0625)

# %%
datainfo = get_datainfo()
datainfo
# Out:
#      Unnamed: 0 filename     area        Ap
# 0             0    0.jpg  100.473  0.004410
# 1             1    1.jpg  127.880  0.009537
# 2             2    2.jpg  161.820  0.008072
# 3             3    3.jpg  190.003  0.008423
# 4             4    4.jpg   22.713  0.002579
# ..          ...      ...      ...       ...
# 350         350  350.jpg   98.599  0.004944
# 351         351  351.jpg   98.599  0.005508
# 352         352  352.jpg   98.599  0.004944
# 353         353  353.jpg   98.599  0.005508
# 354         354  354.jpg   98.599  0.005508
#
# [355 rows x 4 columns]

# %%
F = np.array(list(map(lambda filename: list(pixel_scale_edge(align(rgb2gray(get(filename))))), datainfo.filename.values)))
F
# Out:
# array([[0.06640625, 0.06640625],
#        [0.09765625, 0.09765625],
#        [0.08984375, 0.08984375],
#        [0.09375   , 0.08984375],
#        [0.05078125, 0.05078125],
#        [0.06640625, 0.0625    ],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.0625    , 0.0625    ],
#        [0.06640625, 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.09375   , 0.09375   ],
#        [0.09375   , 0.09375   ],
#        [0.09375   , 0.09375   ],
#        [0.08203125, 0.08984375],
#        [0.08203125, 0.08984375],
#        [0.09375   , 0.09375   ],
#        [0.09375   , 0.09375   ],
#        [0.09375   , 0.09375   ],
#        [0.08984375, 0.08984375],
#        [0.08984375, 0.08984375],
#        [0.08984375, 0.08984375],
#        [0.08984375, 0.08203125],
#        [0.08984375, 0.08203125],
#        [0.08984375, 0.08984375],
#        [0.08984375, 0.08984375],
#        [0.08984375, 0.08984375],
#        [0.078125  , 0.07421875],
#        [0.078125  , 0.07421875],
#        [0.078125  , 0.07421875],
#        [0.07421875, 0.0703125 ],
#        [0.078125  , 0.07421875],
#        [0.07421875, 0.0703125 ],
#        [0.078125  , 0.07421875],
#        [0.078125  , 0.07421875],
#        [0.109375  , 0.109375  ],
#        [0.109375  , 0.109375  ],
#        [0.109375  , 0.109375  ],
#        [0.10546875, 0.10546875],
#        [0.10546875, 0.10546875],
#        [0.109375  , 0.109375  ],
#        [0.109375  , 0.109375  ],
#        [0.109375  , 0.109375  ],
#        [0.08984375, 0.08984375],
#        [0.08984375, 0.08984375],
#        [0.08984375, 0.08984375],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.08984375, 0.08984375],
#        [0.08984375, 0.08984375],
#        [0.08984375, 0.08984375],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.08203125, 0.0859375 ],
#        [0.0859375 , 0.08203125],
#        [0.08203125, 0.0859375 ],
#        [0.078125  , 0.07421875],
#        [0.08203125, 0.078125  ],
#        [0.07421875, 0.078125  ],
#        [0.08203125, 0.08984375],
#        [0.08203125, 0.078125  ],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.08203125, 0.08203125],
#        [0.08203125, 0.08203125],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.0859375 , 0.0859375 ],
#        [0.09375   , 0.09765625],
#        [0.09765625, 0.09375   ],
#        [0.09765625, 0.09375   ],
#        [0.09375   , 0.0859375 ],
#        [0.09375   , 0.0859375 ],
#        [0.09765625, 0.09375   ],
#        [0.09765625, 0.09375   ],
#        [0.09765625, 0.09375   ],
#        [0.09375   , 0.08984375],
#        [0.0859375 , 0.08984375],
#        [0.0859375 , 0.08984375],
#        [0.08984375, 0.08984375],
#        [0.08984375, 0.08984375],
#        [0.08984375, 0.0859375 ],
#        [0.08203125, 0.08984375],
#        [0.0859375 , 0.08984375],
#        [0.0390625 , 0.0390625 ],
#        [0.0390625 , 0.0390625 ],
#        [0.0390625 , 0.0390625 ],
#        [0.0390625 , 0.0390625 ],
#        [0.0390625 , 0.0390625 ],
#        [0.0390625 , 0.0390625 ],
#        [0.0390625 , 0.0390625 ],
#        [0.0390625 , 0.0390625 ],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.05859375],
#        [0.0546875 , 0.0546875 ],
#        [0.0546875 , 0.0546875 ],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.05859375],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.05859375],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0546875 , 0.0546875 ],
#        [0.0546875 , 0.0546875 ],
#        [0.0546875 , 0.0546875 ],
#        [0.05078125, 0.05078125],
#        [0.0546875 , 0.0546875 ],
#        [0.05078125, 0.05078125],
#        [0.0546875 , 0.0546875 ],
#        [0.0546875 , 0.0546875 ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.05859375],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.0546875 ],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.0546875 ],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.05859375],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.0546875 , 0.0546875 ],
#        [0.0546875 , 0.0546875 ],
#        [0.0546875 , 0.05078125],
#        [0.05078125, 0.0546875 ],
#        [0.0546875 , 0.0546875 ],
#        [0.0546875 , 0.0546875 ],
#        [0.0546875 , 0.0546875 ],
#        [0.0546875 , 0.0546875 ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.06640625, 0.0703125 ],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.0703125 ],
#        [0.06640625, 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.05859375, 0.05859375],
#        [0.05859375, 0.05859375],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.0625    ],
#        [0.06640625, 0.0625    ],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.06640625, 0.06640625],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.05859375, 0.0625    ],
#        [0.05859375, 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.0625    , 0.0625    ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.0703125 , 0.0703125 ],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.078125  , 0.078125  ],
#        [0.078125  , 0.078125  ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.0703125 , 0.0703125 ],
#        [0.07421875, 0.07421875],
#        [0.07421875, 0.07421875]])

# %%
fig, ax = plt.subplots()
plt.scatter(*F.T)
ax.set_aspect('equal')

# %%
datainfo['fx'], datainfo['fy'] = F.T
datainfo['Ap'] = datainfo.fx*datainfo.fy
datainfo
# Out:
#      Unnamed: 0 filename     area        Ap        fx        fy
# 0             0    0.jpg  100.473  0.004410  0.066406  0.066406
# 1             1    1.jpg  127.880  0.009537  0.097656  0.097656
# 2             2    2.jpg  161.820  0.008072  0.089844  0.089844
# 3             3    3.jpg  190.003  0.008423  0.093750  0.089844
# 4             4    4.jpg   22.713  0.002579  0.050781  0.050781
# ..          ...      ...      ...       ...       ...       ...
# 350         350  350.jpg   98.599  0.004944  0.070312  0.070312
# 351         351  351.jpg   98.599  0.005508  0.074219  0.074219
# 352         352  352.jpg   98.599  0.004944  0.070312  0.070312
# 353         353  353.jpg   98.599  0.005508  0.074219  0.074219
# 354         354  354.jpg   98.599  0.005508  0.074219  0.074219
#
# [355 rows x 6 columns]

# %%
datainfo.drop(columns='Unnamed: 0').to_csv(path.join(PATH, 'dataset.csv'), index=False)
