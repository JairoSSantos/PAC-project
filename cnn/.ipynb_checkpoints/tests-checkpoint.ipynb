# %%
from models import *
from DScontrol import *
import matplotlib.pyplot as plt

# %% [markdown]
# melhor configuração alcançada:
#
# - hough transform, fourier tranfrorm e gabor filter
# - threshold_kmeans(nclusters=3, nbins=50) -> limitado pelo maior valor de cinza do núcleo mais escuro encontrado (mais à esquerda)
# - opening: 6
# - closing: 0
# - dilation: 2
# - nenhum filtro é aplicado à saída do filtro de gabor (filtered)

# %%
outs = {
    'predict':[],
    'estimated_error':[]
}
gabor_segmentation = FourierGabor(opening=6, closing=0, dilation=2, minimum=0, maximum=0, median=0, nclusters=3, nbins=50)
total = len(DS)
for i, filename in enumerate(DS.filename):
    area, error = gabor_segmentation.predict(get(filename), True)
    outs['predict'].append(area)
    outs['estimated_error'].append(error)
    print(f'{i+1}/{total}|{(i/total*100):.2f}%', end='\r')
# Out:
# 355/355|99.72%

# %%
dss = pd.concat([DS, pd.DataFrame(outs)], axis=1).sort_values('area', ignore_index=True)
dss['error'] = dss.area - dss.predict
dss['error_rel'] = np.abs(dss.error)/dss.area*100

# %%
#t = range(len(dss))
plt.plot(dss.area, '.', label='Valor real')
plt.plot(dss.predict, '+', c='tab:red', label='Valor encontrado', lw=0.7)
plt.ylabel(r'Área ($mm^2$)')
plt.xlabel('Amostra')
plt.legend()
plt.show()

# %%
#t = range(len(dss))
plt.plot(dss.area, dss.predict, 'o', alpha=0.5)
plt.xlabel(r'Área Real ($mm^2$)')
plt.ylabel(r'Área Encontrada ($mm^2$)')
#plt.legend()
plt.show()

# %%
dss.error_rel.describe()
# Out:
# count    355.000000
# mean       5.038454
# std        8.282124
# min        0.003779
# 25%        1.580822
# 50%        4.283467
# 75%        6.169503
# max       87.310514
# Name: error_rel, dtype: float64

# %%
dss.to_csv('dss_predict.csv', index=False)
